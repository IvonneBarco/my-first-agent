# %%
import os
from  dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model("openai:gpt-4o", temperature=0)

# %%
openai_vector_store_ids = [
    "vs_696aa449413c8191b40ac97651032d94"
]

file_search_tools = {
    "type": "file_search",
    "vector_store_ids": openai_vector_store_ids,
}

llm_with_tools = llm.bind_tools([file_search_tools])

# %%
response = llm_with_tools.invoke("Por qué los Agentes de IA son importantes para las empresas emergentes?")
response.text
# Out:
# 'Los agentes de IA son importantes para las empresas emergentes por varias razones:\n\n1. **Automatización de Procesos Complejos**: Los agentes de IA permiten a las startups automatizar flujos de trabajo complejos, lo que puede mejorar la eficiencia operativa y reducir costos.\n\n2. **Innovación en Experiencia de Usuario**: Pueden crear experiencias de usuario novedosas, lo que ayuda a diferenciar a las startups en mercados competitivos.\n\n3. **Resolución de Problemas**: Los agentes de IA pueden abordar problemas de negocio que antes eran técnicamente inviables, permitiendo a las startups ofrecer soluciones únicas.\n\n4. **Escalabilidad**: Las soluciones de IA pueden escalar sin convertirse en un cuello de botella, lo que es crucial para el crecimiento de las startups.\n\n5. **Ventaja Competitiva**: Un enfoque disciplinado en el desarrollo de agentes de IA proporciona una ventaja competitiva al permitir iterar e innovar más rápidamente.\n\n6. **Integración y Flexibilidad**: Los agen
# ...

# %%
response = llm_with_tools.invoke("Hola, cómo estás?")
response.text
# Out:
# '¡Hola! Estoy bien, gracias. ¿En qué puedo ayudarte hoy?'
