# %%
from langchain_core.prompts import PromptTemplate

template = """\
# Instricciones para el asistente de IA

Recuerda que hoy es {fecha_actual}

## Rol
Eres un experto en marketing digital con 10 años de experiencia.

## Tarea
Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocandote en el llamado a la accion.

## Texto del anuncio
{texto_anuncio}

## Formato de salida
- *Sugerencia 1:* [Tu primera sugerencia]
- *Sugerencia 2:* [Tu segunda sugerencia]
- *Sugerencia 3:* [Tu tercera sugerencia]
"""

prompt_template = PromptTemplate.from_template(template)
prompt = prompt_template.format(fecha_actual="2024-06-15", texto_anuncio="Compra nuestro producto ahora y obtén un 20% de descuento!")
print(prompt)
# Out:
# # Instricciones para el asistente de IA
#
# Recuerda que hoy es 2024-06-15
#
# ## Rol
# Eres un experto en marketing digital con 10 años de experiencia.
#
# ## Tarea
# Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocandote en el llamado a la accion.
#
# ## Texto del anuncio
# Compra nuestro producto ahora y obtén un 20% de descuento!
#
# ## Formato de salida
# - *Sugerencia 1:* [Tu primera sugerencia]
# - *Sugerencia 2:* [Tu segunda sugerencia]
# - *Sugerencia 3:* [Tu tercera sugerencia]

# %%
import datetime


today = datetime.datetime.now().strftime("%Y-%m-%d")
prompt_template = PromptTemplate.from_template(template, partial_variables={"fecha_actual": today})
prompt = prompt_template.format(texto_anuncio="Compra nuestro producto ahora y obtén un 20% de descuento!")
print(prompt)
# Out:
# # Instricciones para el asistente de IA
#
# Recuerda que hoy es 2026-01-20
#
# ## Rol
# Eres un experto en marketing digital con 10 años de experiencia.
#
# ## Tarea
# Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocandote en el llamado a la accion.
#
# ## Texto del anuncio
# Compra nuestro producto ahora y obtén un 20% de descuento!
#
# ## Formato de salida
# - *Sugerencia 1:* [Tu primera sugerencia]
# - *Sugerencia 2:* [Tu segunda sugerencia]
# - *Sugerencia 3:* [Tu tercera sugerencia]

# %%
template = """\
Your are a helpful that responds to the user's message

{% if name %}
The user's name is {name} and you can call them by that name
{% endif -%}
the user's message is: {{user_message}}
"""

prompt_template = PromptTemplate.from_template(template, template_format="jinja2")
prompt = prompt_template.format(user_message="Por qué los Agentes de IA son importantes para las empresas emergentes?")
print(prompt)
# Out:
# Your are a helpful that responds to the user's message
#
# the user's message is: Por qué los Agentes de IA son importantes para las empresas emergentes?
